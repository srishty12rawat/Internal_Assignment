# %%
import pandas as pd

# %%
sheet = pd.read_excel('death-data.xlsx', skiprows=6)

# %%
sheet
# Out:
#      Unnamed: 0                                       GBD code Unnamed: 2  \
# 0           NaN                                            NaN        NaN
# 1           NaN                                            NaN        NaN
# 2           NaN                                            NaN        NaN
# 3           NaN                                            NaN        NaN
# 4           NaN                                            NaN        NaN
# ..          ...                                            ...        ...
# 135         NaN                                           W158        NaN
# 136         NaN                                           W159        NaN
# 137         NaN                                            NaN        NaN
# 138         NaN                                            NaN        NaN
# 139         NaN  Refer to Notes sheet for notes on this table.        NaN
#
#                         GBD cause (b)                    Unnamed: 4  \
# ...

# %%
sheet.drop([1,2,3,4,6,7,8,9,137,138,139], axis = 0, inplace = True)

# %%
sheet.head(40)
# Out:
#     Unnamed: 0 GBD code Unnamed: 2  \
# 0          NaN      NaN        NaN
# 5          NaN      NaN        NaN
# 10         NaN     W001         I.
# 11         NaN     W002        NaN
# 12         NaN     W003        NaN
# 13         NaN     W004        NaN
# 14         NaN     W005        NaN
# 15         NaN     W006        NaN
# 16         NaN     W007        NaN
# 17         NaN     W009        NaN
# 18         NaN     W010        NaN
# 19         NaN     W011        NaN
# 20         NaN     W012        NaN
# 21         NaN     W013        NaN
# 22         NaN     W014        NaN
# 23         NaN     W015        NaN
# 24         NaN     W016        NaN
# 25         NaN     W017        NaN
# 26         NaN     W018        NaN
# 27         NaN     W019        NaN
# 28         NaN     W020        NaN
# 29         NaN     W021        NaN
# 30         NaN     W022        NaN
# 31         NaN     W023        NaN
# 32         NaN     W024        NaN
# ...

# %%
sheet.drop(['Unnamed: 0', 'GBD code'], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-aa43e8fb7064> in <module>
# ----> 1 sheet.drop(['Unnamed: 0', 'GBD code'], axis = 1, inplace = True)
#
# c:\users\srishty.rawat\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# c:\users\srishty.rawat\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
sheet.rename(columns = {'GBD cause (b)': 'Level 1', 'Unnamed: 4': 'Level 2', 'Unnamed: 5':'Level 3', 'Unnamed: 6':'Level 4' }, 
             inplace = True)

# %%
sheet.head(40)
# Out:
#    Unnamed: 2                                            Level 1  \
# 0         NaN                                                NaN
# 5         NaN                              Population ('000) (e)
# 10         I.  Communicable, maternal, perinatal and nutritio...
# 11        NaN                                                 A.
# 12        NaN                                                NaN
# 13        NaN                                                NaN
# 14        NaN                                                NaN
# 15        NaN                                                NaN
# 16        NaN                                                NaN
# 17        NaN                                                NaN
# 18        NaN                                                NaN
# 19        NaN                                                NaN
# 20        NaN                                                NaN
# ...

# %%
rows_count = sheet.shape[0]

# %%
rows_count
# Out:
# 129

# %%
value = sheet.iat[128,3]

# %%
value
# Out:
# nan

# %%
a = sheet.isnull().iloc[4,1]

# %%
for col in range(3, 0, -1):
    for row in range(3, rows_count):
            if (sheet.isnull().iloc[row, col-1]):
                sheet.iloc[row, col] = sheet.iloc[row-1, col]

# %%
sheet.head(40)
# Out:
#    Unnamed: 2                                            Level 1  \
# 0         NaN                                                NaN
# 5         NaN                              Population ('000) (e)
# 10         I.  Communicable, maternal, perinatal and nutritio...
# 11        NaN  Communicable, maternal, perinatal and nutritio...
# 12        NaN  Communicable, maternal, perinatal and nutritio...
# 13        NaN  Communicable, maternal, perinatal and nutritio...
# 14        NaN  Communicable, maternal, perinatal and nutritio...
# 15        NaN  Communicable, maternal, perinatal and nutritio...
# 16        NaN  Communicable, maternal, perinatal and nutritio...
# 17        NaN  Communicable, maternal, perinatal and nutritio...
# 18        NaN  Communicable, maternal, perinatal and nutritio...
# 19        NaN  Communicable, maternal, perinatal and nutritio...
# 20        NaN  Communicable, maternal, perinatal and nutritio...
# ...

# %%
countries = list(sheet.columns)

# %%
len(a)
# Out:
# 197

# %%
Export = sheet.to_json(r'C:\Users\srishty.rawat\Desktop\Assignment\Internal_Assignment\Final.json',orient='split')

# %%
Export

# %%
import json
from pymongo import MongoClient

# %%
client = MongoClient('localhost', 27017)
db = client['death_rate']

# %%
collection_death = db['death_datas']

# %%
with open('final.json') as f:
    file_data = json.load(f)

# %%
collection_death.insert_one(file_data)  
client.close()

# %%
Export = sheet.to_csv(r'C:\Users\srishty.rawat\Desktop\Assignment\Internal_Assignment\Final.csv')

# %%
for x in range (0,5):
    countries.pop(x)
