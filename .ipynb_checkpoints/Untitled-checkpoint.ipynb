# %%
import pandas as pd

# %%
sheet = pd.read_excel('death-data.xlsx')

# %%
sheet
# Out:
#      Unnamed: 0                                     Unnamed: 1 Unnamed: 2  \
# 0           NaN                                            NaN        NaN
# 1           NaN                                            NaN        NaN
# 2           NaN                                            NaN        NaN
# 3           NaN                                            NaN        NaN
# 4           NaN                                            NaN        NaN
# ..          ...                                            ...        ...
# 141         NaN                                           W158        NaN
# 142         NaN                                           W159        NaN
# 143         NaN                                            NaN        NaN
# 144         NaN                                            NaN        NaN
# 145         NaN  Refer to Notes sheet for notes on this table.        NaN
#
#     Unnamed: 3 Unnamed: 4           World Health Organization Unnamed: 6  \
# ...

# %%
sheet.drop(["Unnamed: 0", "Unnamed: 1"], axis = 1, inplace = True)

# %%
sheet.rename(columns = { 'Unnamed: 0':'del1', 'Unnamed: 1':'del2'},inplace = True)

# %%
sheet
# Out:
#     Unnamed: 2 Unnamed: 3 Unnamed: 4           World Health Organization  \
# 0          NaN        NaN        NaN   Organisation Mondiale de la Santé
# 1          NaN        NaN        NaN                       Department of
# 2          NaN        NaN        NaN  Measurement and Health Information
# 3          NaN        NaN        NaN                       February 2009
# 4          NaN        NaN        NaN                                 NaN
# ..         ...        ...        ...                                 ...
# 141        NaN        NaN         2.                            Violence
# 142        NaN        NaN         3.                                 War
# 143        NaN        NaN        NaN                                 NaN
# 144        NaN        NaN        NaN                                 NaN
# 145        NaN        NaN        NaN                                 NaN
#
#     Unnamed: 6                                         Unnamed: 7 Unnamed: 8  \
# ...

# %%
sheet.drop([0,1,2,3,4,8,9], axis = 0, inplace = True)

# %%
sheet
# Out:
#     Unnamed: 2                        Unnamed: 3 Unnamed: 4  \
# 5          NaN                     GBD cause (b)        NaN
# 6          NaN                               NaN        NaN
# 7          NaN  Data sources - level of evidence        NaN
# 10         NaN                               NaN        NaN
# 11         NaN             Population ('000) (e)        NaN
# ..         ...                               ...        ...
# 141        NaN                               NaN         2.
# 142        NaN                               NaN         3.
# 143        NaN                               NaN        NaN
# 144        NaN                               NaN        NaN
# 145        NaN                               NaN        NaN
#
#     World Health Organization        Unnamed: 6   Unnamed: 7 Unnamed: 8  \
# 5                         NaN               NaN  Afghanistan    Albania
# 6                         NaN  WHO Country code         3010       4005
# ...

# %%
sheet.columns = sheet.iloc[5]

# %%
sheet.drop(sheet.index[5])
# Out:
# 12   NaN                               NaN  NaN       NaN               NaN  \
# 5    NaN                     GBD cause (b)  NaN       NaN               NaN
# 6    NaN                               NaN  NaN       NaN  WHO Country code
# 7    NaN  Data sources - level of evidence  NaN       NaN               NaN
# 10   NaN                               NaN  NaN       NaN               NaN
# 11   NaN             Population ('000) (e)  NaN       NaN               NaN
# ..   ...                               ...  ...       ...               ...
# 141  NaN                               NaN   2.  Violence               NaN
# 142  NaN                               NaN   3.       War               NaN
# 143  NaN                               NaN  NaN       NaN               NaN
# 144  NaN                               NaN  NaN       NaN               NaN
# 145  NaN                               NaN  NaN       NaN               NaN
#
# ...

# %%
sheet.drop([12], axis = 0, inplace = True)

# %%
sheet
# Out:
# 12   NaN                               NaN  NaN       NaN               NaN  \
# 5    NaN                     GBD cause (b)  NaN       NaN               NaN
# 6    NaN                               NaN  NaN       NaN  WHO Country code
# 7    NaN  Data sources - level of evidence  NaN       NaN               NaN
# 10   NaN                               NaN  NaN       NaN               NaN
# 11   NaN             Population ('000) (e)  NaN       NaN               NaN
# ..   ...                               ...  ...       ...               ...
# 141  NaN                               NaN   2.  Violence               NaN
# 142  NaN                               NaN   3.       War               NaN
# 143  NaN                               NaN  NaN       NaN               NaN
# 144  NaN                               NaN  NaN       NaN               NaN
# 145  NaN                               NaN  NaN       NaN               NaN
#
# ...
